# %%
print("Day - 1 - Python for automation begins")
# Out:
# Day - 1 - Python for automation begins

# %%
#Variables - storing information
temperature = 75.5
machine_name = "Conveyor Belt A"
is_running = True
motor_speed = 1200

print(temperature)
print(machine_name)
print(is_running)
print(motor_speed)
# Out:
# 75.5
# Conveyor Belt A
# True
# 1200

# %%
print(type(temperature))
print(type(machine_name))
print(type(is_running))
print(type(motor_speed))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>

# %%
temperature_celcius = 75.5
temperature_fahrenheit = (temperature_celcius*9/5)+32

# %%
motor_speed = 1200
reduced_speed = motor_speed * 0.75

# %%
parts_produced = 450
parts_per_hour = parts_produced / 8

# %%
print("Temp in F:", temperature_fahrenheit)
print("Reduced speed:", reduced_speed)
print("parts per hour:", parts_per_hour)
# Out:
# Temp in F: 167.9
# Reduced speed: 900.0
# parts per hour: 56.25

# %%
machine_name = "Conveyor belt A"
temperature = 75.5
motor_speed = 900.0
is_running = True

print(f"Machine: {machine_name}")
print(f"Temperature: {temperature} °C")
print(f"Motor Speed: {motor_speed} RPM")
print(f"status: {is_running}")
# Out:
# Machine: Conveyor belt A
# Temperature: 75.5 °C
# Motor Speed: 900.0 RPM
# status: True

# %%
#Getting input from operator
machine_name = input("Enter Machine Name: ")
temperature = float(input("Enter current temperature: "))

print(f"\nMachine: {machine_name}")
print(f"\nTemperature: {temperature}°C")

if temperature > 80:
    print("WARNING: Temperature too high")
else:
    print("Temperature is normal")
# Out:
# Enter Machine Name:  Conveyor Belt A
# Enter current temperature:  80.1
# Machine: Conveyor Belt A
#
# Temperature: 80.1°C
# WARNING: Temperature too high

# %%
# DAY 1 SUMMARY
# learned: variables, data types, math functions, fstrings, input, if/else
# Next: loops and lists
